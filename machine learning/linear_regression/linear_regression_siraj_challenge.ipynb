# %% [markdown]
# ## Linear regression challenge by siraj

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
# %matplotlib inline
import matplotlib.pyplot as plt

# read data
df = pd.read_csv('datasets/challenge_dataset.txt', sep=',', names=['x', 'y'])
# x_values = df['x'].values.reshape(-1, 1)
# y_values = df['y'].values
print('len(x)={}, len(y)={}'.format(len(x_values), len(y_values)))

# fit model
body_reg = linear_model.LinearRegression()
body_reg.fit(df[['x']], df[['y']])
predicted_y = body_reg.predict(df[['x']])

# visualize results
plt.figure(1, figsize=(15, 7))
plt.plot(df[['x']], df[['y']], 'bo', df[['x']], predicted_y, 'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
# Out:
# len(x)=97, len(y)=97
